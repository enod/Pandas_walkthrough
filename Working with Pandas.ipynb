# %%
import pandas as pd

# %%
fbdata = pd.read_csv('/Users/enod/Development/fb-scrape/facebook-page-post-scraper/156915824368931_facebook_statuses.csv')

# %%
type(fbdata.status_message)
# Out:
# pandas.core.series.Series

# %%
fbdata.shape
# Out:
# (3212, 15)

# %%
fbdata['test_column'] = ''

# %%
fbdata.head()
# Out:
#                           status_id  \
# 0  156915824368931_1125851687475335
# 1  156915824368931_1125254910868346
# 2  156915824368931_1125189747541529
# 3  156915824368931_1125116847548819
# 4  156915824368931_1123607134366457
#
#                                       status_message            link_name  \
# 0                    Өнөөдөр орой хүлээн авч үзээрэй      Timeline Photos
# 1  "Бригад" реалити шоуны оролцогчид Сэлэнгэ айма...                  NaN
# 2                                 Бригад реалити шоу  Шууд эфир /туршилт/
# 3                          Өнөөдөр орой манай ТВ-ээр      Timeline Photos
# 4                                          Өнөө орой      Timeline Photos
#
#   status_type                                        status_link  \
# 0       photo  https://www.facebook.com/mongoltv/photos/a.349...
# 1       video  https://www.facebook.com/mongoltv/videos/11252...
# 2       video  https://www.facebook.com/mongoltv/videos/11251...
# ...

# %%
fbdata.dtypes
# Out:
# status_id           object
# status_message      object
# link_name           object
# status_type         object
# status_link         object
# status_published    object
# num_reactions        int64
# num_comments         int64
# num_shares           int64
# num_likes            int64
# num_loves            int64
# num_wows             int64
# num_hahas            int64
# num_sads             int64
# num_angrys           int64
# test_column         object
# dtype: object

# %%
fbdata.describe(include=['object'])
# Out:
#                                status_id  \
# count                               3212
# unique                              3210
# top     156915824368931_1110432945683876
# freq                                   2
#
#                                            status_message        link_name  \
# count                                                2649             2413
# unique                                               2560              910
# top     Фэйсбүүкээр санал авахгүй бөгөөд санал хураалт...  Timeline Photos
# freq                                                    7              532
#
#        status_type                             status_link  \
# count         3212                                    2748
# unique           5                                    2667
# top          video  https://www.mongoltv.mn/live/#schedule
# freq          1023                                       4
#
#            status_published test_column
# ...

# %%
fbdata.columns
# Out:
# Index(['status_id', 'status_message', 'link_name', 'status_type',
#        'status_link', 'status_published', 'num_reactions', 'num_comments',
#        'num_shares', 'num_likes', 'num_loves', 'num_wows', 'num_hahas',
#        'num_sads', 'num_angrys', 'test_column'],
#       dtype='object')

# %% [markdown]
# # Renaming specific column/columns

# %%
fbdata.rename(columns= {'test_column':'Test_column'}, inplace=True)

# %% [markdown]
# ### Deleting column - axis=1 нь column-г илтгэнэ 0 бол rows-г илтгэнэ

# %%
fbdata.drop('Test_column', axis=1, inplace=True)

# %%
fbdata.columns
# Out:
# Index(['status_id', 'status_message', 'link_name', 'status_type',
#        'status_link', 'status_published', 'num_reactions', 'num_comments',
#        'num_shares', 'num_likes', 'num_loves', 'num_wows', 'num_hah
# 42    156915824368931_1108908042503033
# 44    156915824368931_1108890765838094
# ...

# %% [markdown]
# #### Үүнээсээ цаашлаад зөвхөн тодорхой талбаруудыг сонгож болно

# %%
fbdata[fbdata['num_reactions'] >= 100]['status_message'].head()
# Out:
# 2                                    Бригад реалити шоу
# 5     "Бригад" реалити шоуны шинэ дугаар 08-р сарын ...
# 6            "Авьяаслаг Монголчууд 2016" тун удахгүй...
# 9     МонголTV "Олон улсын эрэн сурвалжлах сэтгүүлчд...
# 12    Үзэгчдийн хүсэлтээр "Боолын ангууч" СОАК 7-р с...
# Name: status_message, dtype: object

# %% [markdown]
# ### How to apply multiple filters to pandas dataframe?

# %%
fbdata[(fbdata['num_reactions'] >= 100) & (fbdata['status_type'] == 'photo')].head()
# Out:
#                            status_id  \
# 9   156915824368931_1116179375109233
# 12  156915824368931_1114286788631825
# 13  156915824368931_1114026441991193
# 27  156915824368931_1109293149131189
# 44  156915824368931_1108890765838094
#
#                                        status_message  \
# 9   МонголTV "Олон улсын эрэн сурвалжлах сэтгүүлчд...
# 12  Үзэгчдийн хүсэлтээр "Боолын ангууч" СОАК 7-р с...
# 13                                                NaN
# 27                                            Гоё уу?
# 44                                   Соёолон эргэлээ.
#
#                        link_name status_type  \
# 9   Photos from Mongol TV's post       photo
# 12               Timeline Photos       photo
# 13       Mongol TV's cover photo       photo
# 27               Timeline Photos       photo
# 44  Photos from Mongol TV's post       photo
#
#                                           status_link     status_published  \
# ...

# %% [markdown]
# Эсвэл OR оператор дараах байдлаар мөн ашиглаж болох нь:

# %%
fbdata[(fbdata['num_reactions'] >= 100) | (fbdata['status_type'] == 'photo')].head()
# Out:
#                           status_id  \
# 0  156915824368931_1125851687475335
# 2  156915824368931_1125189747541529
# 3  156915824368931_1125116847548819
# 4  156915824368931_1123607134366457
# 5  156915824368931_1123077857752718
#
#                                       status_message            link_name  \
# 0                    Өнөөдөр орой хүлээн авч үзээрэй      Timeline Photos
# 2                                 Бригад реалити шоу  Шууд эфир /туршилт/
# 3                          Өнөөдөр орой манай ТВ-ээр      Timeline Photos
# 4                                          Өнөө орой      Timeline Photos
# 5  "Бригад" реалити шоуны шинэ дугаар 08-р сарын ...                  NaN
#
#   status_type                                        status_link  \
# 0       photo  https://www.facebook.com/mongoltv/photos/a.349...
# 2       video  https://www.facebook.com/mongoltv/videos/11251...
# 3       photo  https://www.facebook.com/mongoltv/photos/a.349...
# ...

# %% [markdown]
# Хэд хэдэн OR нөхцөлтэй бол дараах байдлаар isin ашиглаад шийдэж болно:

# %%
fbdata[fbdata['status_type'].isin(['photo','video'])].head()
# Out:
#                           status_id  \
# 0  156915824368931_1125851687475335
# 1  156915824368931_1125254910868346
# 2  156915824368931_1125189747541529
# 3  156915824368931_1125116847548819
# 4  156915824368931_1123607134366457
#
#                                       status_message            link_name  \
# 0                    Өнөөдөр орой хүлээн авч үзээрэй      Timeline Photos
# 1  "Бригад" реалити шоуны оролцогчид Сэлэнгэ айма...                  NaN
# 2                                 Бригад реалити шоу  Шууд эфир /туршилт/
# 3                          Өнөөдөр орой манай ТВ-ээр      Timeline Photos
# 4                                          Өнөө орой      Timeline Photos
#
#   status_type                                        status_link  \
# 0       photo  https://www.facebook.com/mongoltv/photos/a.349...
# 1       video  https://www.facebook.com/mongoltv/videos/11252...
# 2       video  https://www.facebook.com/mongoltv/videos/11251...
# ...

# %%
fbdata.head()
# Out:
#                           status_id  \
# 0  156915824368931_1125851687475335
# 1  156915824368931_1125254910868346
# 2  156915824368931_1125189747541529
# 3  156915824368931_1125116847548819
# 4  156915824368931_1123607134366457
#
#                                       status_message            link_name  \
# 0                    Өнөөдөр орой хүлээн авч үзээрэй      Timeline Photos
# 1  "Бригад" реалити шоуны оролцогчид Сэлэнгэ айма...                  NaN
# 2                                 Бригад реалити шоу  Шууд эфир /туршилт/
# 3                          Өнөөдөр орой манай ТВ-ээр      Timeline Photos
# 4                                          Өнөө орой      Timeline Photos
#
#   status_type                                        status_link  \
# 0       photo  https://www.facebook.com/mongoltv/photos/a.349...
# 1       video  https://www.facebook.com/mongoltv/videos/11252...
# 2       video  https://www.facebook.com/mongoltv/videos/11251...
# ...

# %%
fbcomment = pd.read_csv('/Users/enod/Development/fb-scrape/facebook-page-post-scraper/156915824368931_facebook_comments.csv')

# %%
fbcomment.head()
# Out:
#                           comment_id                         status_id  \
# 0  1118055131588324_1118058484921322  156915824368931_1118055131588324
# 1  1118055131588324_1118066601587177  156915824368931_1118055131588324
# 2  1118055131588324_1118080791585758  156915824368931_1118055131588324
# 3  1118055131588324_1118208254906345  156915824368931_1118055131588324
# 4  1118055131588324_1118570608203443  156915824368931_1118055131588324
#
#   parent_id                                    comment_message  \
# 0       NaN  ХИЙГЭЭГҮЙ ХЭРГИЙН ТӨЛӨӨ НАМАЙГ БУРУУТГАЖ ЗАЛИЛ...
# 1       NaN                   kkk, buun modeluud ain, za uziy,
# 2       NaN                  Wowldoo huuhlduu huurhun l bnshde
# 3       NaN                          Page huudas bdiin   boluu
# 4       NaN                                           Teneguud
#
#          comment_author    comment_published  comment_likes
# 0            Bai Puujee  2016-07-25 02:12:51              0
# ...

# %% [markdown]
# ## Зөвхөн тоон утгатай талбаруудыг сонгох бол

# %%
import numpy as np

# %%
fbdata.select_dtypes(include=[np.number]).head()
# Out:
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0             44             6           1         44          0         0
# 1             34             0          12         32          2         0
# 2            293            52          39        276          9         4
# 3             63            18           3         59          1         1
# 4             56            14           1         56          0         0
#
#    num_hahas  num_sads  num_angrys
# 0          0         0           0
# 1          0         0           0
# 2          1         1           2
# 3          1         0           1
# 4          0         0           0

# %% [markdown]
# ### Axis параметр хэрхэн ашиглах вэ?

# %%
fbdata.head()
# Out:
#                           status_id  \
# 0  156915824368931_1125851687475335
# 1  156915824368931_1125254910868346
# 2  156915824368931_1125189747541529
# 3  156915824368931_1125116847548819
# 4  156915824368931_1123607134366457
#
#                                       status_message            link_name  \
# 0                    Өнөөдөр орой хүлээн авч үзээрэй      Timeline Photos
# 1  "Бригад" реалити шоуны оролцогчид Сэлэнгэ айма...                  NaN
# 2                                 Бригад реалити шоу  Шууд эфир /туршилт/
# 3                          Өнөөдөр орой манай ТВ-ээр      Timeline Photos
# 4                                          Өнөө орой      Timeline Photos
#
#   status_type                                        status_link  \
# 0       photo  https://www.facebook.com/mongoltv/photos/a.349...
# 1       video  https://www.facebook.com/mongoltv/videos/11252...
# 2       video  https://www.facebook.com/mongoltv/videos/11251...
# ...

# %% [markdown]
# Доорхид link_name нь column учраас бид axis=1 гэж зааж өгнө

# %%
fbdata.drop('link_name', axis=1).head()
# Out:
#                           status_id  \
# 0  156915824368931_1125851687475335
# 1  156915824368931_1125254910868346
# 2  156915824368931_1125189747541529
# 3  156915824368931_1125116847548819
# 4  156915824368931_1123607134366457
#
#                                       status_message status_type  \
# 0                    Өнөөдөр орой хүлээн авч үзээрэй       photo
# 1  "Бригад" реалити шоуны оролцогчид Сэлэнгэ айма...       video
# 2                                 Бригад реалити шоу       video
# 3                          Өнөөдөр орой манай ТВ-ээр       photo
# 4                                          Өнөө орой       photo
#
#                                          status_link     status_published  \
# 0  https://www.facebook.com/mongoltv/photos/a.349...  2016-08-05 04:16:11
# 1  https://www.facebook.com/mongoltv/videos/11252...  2016-08-04 07:39:04
# 2  https://www.facebook.com/mongoltv/videos/11251...  2016-08-04 04:39:58
# ...

# %% [markdown]
# Хэрэв column бус row устгах бол axis=0 гэж тодотгоод индексээ заана

# %%
fbdata.drop(0,axis=0).head()
# Out:
#                           status_id  \
# 1  156915824368931_1125254910868346
# 2  156915824368931_1125189747541529
# 3  156915824368931_1125116847548819
# 4  156915824368931_1123607134366457
# 5  156915824368931_1123077857752718
#
#                                       status_message            link_name  \
# 1  "Бригад" реалити шоуны оролцогчид Сэлэнгэ айма...                  NaN
# 2                                 Бригад реалити шоу  Шууд эфир /туршилт/
# 3                          Өнөөдөр орой манай ТВ-ээр      Timeline Photos
# 4                                          Өнөө орой      Timeline Photos
# 5  "Бригад" реалити шоуны шинэ дугаар 08-р сарын ...                  NaN
#
#   status_type                                        status_link  \
# 1       video  https://www.facebook.com/mongoltv/videos/11252...
# 2       video  https://www.facebook.com/mongoltv/videos/11251...
# 3       photo  https://www.facebook.com/mongoltv/photos/a.349...
# ...

# %% [markdown]
# .drop method яг ч ориг хувилбарт өөрчлөлт хийдэггүй. fbdata.head() гэвэл өгөгдөл өөрчлөгдөөгүй хуучнаараа байгааа

# %%
fbdata.mean() # доошоо чиглэлтэй тооцоолол хийх
# Out:
# num_reactions    489.558219
# num_comments      43.673101
# num_shares        49.074720
# num_likes        481.181507
# num_loves          2.684620
# num_wows           2.127024
# num_hahas          1.196451
# num_sads           0.700498
# num_angrys         1.662516
# dtype: float64

# %%
fbdata.mean(axis=1).head() # баруун чиглэлтэй тооцоолол хийх
# Out:
# 0    10.555556
# 1     8.888889
# 2    75.222222
# 3    16.333333
# 4    14.111111
# dtype: float64

# %% [markdown]
# ### How to use string methods in pandas?

# %% [markdown]
# String-тэй ажиллах бол str method ашиглаж ардаас нь функцээ бичих хэрэгтэй

# %%
fbdata['status_message'].str.upper().head()
# Out:
# 0                      ӨНӨӨДӨР ОРОЙ ХҮЛЭЭН АВЧ ҮЗЭЭРЭЙ
# 1    "БРИГАД" РЕАЛИТИ ШОУНЫ ОРОЛЦОГЧИД СЭЛЭНГЭ АЙМА...
# 2                                   БРИГАД РЕАЛИТИ ШОУ
# 3                            ӨНӨӨДӨР ОРОЙ МАНАЙ ТВ-ЭЭР
# 4                                            ӨНӨӨ ОРОЙ
# Name: status_message, dtype: object

# %%
import re

# %%
fbdata[fbdata.status_message.notnull()& fbdata['status_message'].str.contains('Авьяаслаг Монголчууд')]
# Out:
#                              status_id  \
# 6     156915824368931_1123082511085586
# 374   156915824368931_1068170083243496
# 391   156915824368931_1066371356756702
# 432   156915824368931_1062501833810321
# 450   156915824368931_1059208190806352
# 470   156915824368931_1058059854254519
# 560   156915824368931_1048242805236224
# 568   156915824368931_1045797675480737
# 591   156915824368931_1040151132712058
# 615   156915824368931_1037113896349115
# 616   156915824368931_1037104633016708
# 641   156915824368931_1030754853651686
# 651   156915824368931_1028590887201416
# 661   156915824368931_1024144327646072
# 695   156915824368931_1017426781651160
# 697   156915824368931_1017397378320767
# 777   156915824368931_1003452223048616
# 846    156915824368931_985560664837772
# 855    156915824368931_983867145007124
# 858    156915824368931_982963078430864
# 863    156915824368931_981829361877569
# 883    156915824368931_976558345738004
# 885    156915824368931_976498762410629
# ...

# %%
fbdata[fbdata.status_message.notnull()& fbdata['status_message'].str.contains('Авьяаслаг')].sort_values('status_published')
# Out:
#                              status_id  \
# 1668   156915824368931_828700350523805
# 1662   156915824368931_830849593642214
# 1659   156915824368931_831393516921155
# 1658   156915824368931_831823703544803
# 1657   156915824368931_831824320211408
# 1656   156915824368931_832015523525621
# 1652   156915824368931_832774263449747
# 1651   156915824368931_832964770097363
# 1649   156915824368931_834029839990856
# 1637   156915824368931_840982795962227
# 1636   156915824368931_841351665925340
# 1635   156915824368931_841352882591885
# 1625   156915824368931_845314065529100
# 1612   156915824368931_847601021967071
# 1604   156915824368931_848923381834835
# 1597   156915824368931_849496895110817
# 1596   156915824368931_849505308443309
# 1592   156915824368931_849602971766876
# 1560   156915824368931_862909240436249
# 1550   156915824368931_864284390298734
# 1549   156915824368931_864395836954256
# 1418   156915824368931_918981821495657
# 1407   156915824368931_921399721253867
# ...

# %% [markdown]
# #### str.replace method-н жишээ: мөн chain буюу 2 дахь replace method залгаж болдог

# %%
fbdata[fbdata.status_message.notnull()& fbdata['status_message'].str.contains('Авьяаслаг')].sort_values('status_published')['status_link'].str.replace('https://','').str.replace('watch','харах').head()
# Out:
# 1668    www.youtube.com/харах?v=kkpTIPTocx4&feature=yo...
# 1662                  www.youtube.com/харах?v=kie5lfknP_g
# 1659    www.facebook.com/mongoltv/videos/831393516921155/
# 1658    www.facebook.com/mongoltv/videos/831823703544803/
# 1657    www.facebook.com/mongoltv/videos/831824320211408/
# Name: status_link, dtype: object

# %% [markdown]
# Мөн regex ашиглаж болно

# %%
fbdata[fbdata.status_message.notnull()& fbdata['status_message'].str.contains('Авьяаслаг')].sort_values('status_published')['status_link'].str.replace('[https://]','').head()
# Out:
# 1668    www.youube.comwac?v=kkTIPTocx4&feaure=youu.be
# 1662                  www.youube.comwac?v=kie5lfknP_g
# 1659      www.facebook.commongolvvideo831393516921155
# 1658      www.facebook.commongolvvideo831823703544803
# 1657      www.facebook.commongolvvideo831824320211408
# Name: status_link, dtype: object

# %% [markdown]
# ### How to change data type of pandas Series?

# %%
fbdata.dtypes
# Out:
# status_id           object
# status_message      object
# link_name           object
# status_type         object
# status_link         object
# status_published    object
# num_reactions        int64
# num_comments         int64
# num_shares           int64
# num_likes            int64
# num_loves            int64
# num_wows             int64
# num_hahas            int64
# num_sads             int64
# num_angrys           int64
# dtype: object

# %% [markdown]
# ###### .astype(type) method ашиглаад тухайн series-ээ дараах байдлаар хөрвүүлж болдог

# %%
fbdata['num_loves'].astype(float).head()
# Out:
# 0    0.0
# 1    2.0
# 2    9.0
# 3    1.0
# 4    0.0
# Name: num_loves, dtype: float64

# %% [markdown]
# ###### fb['num_loves'] = fbdata['num_loves'].astype(float) командаар хувиргаж болно. Ихэвчлэн талбар str байхад float эсвэл int-рүү хувиргах нь зөв кэйс байдаг

# %% [markdown]
# ###### Анх file-аа дуудаж байхдаа мөн өгөгдлийн төрлөө зааж өгч болдог. Жишээ нь:

# %% [markdown]
# ###### fbdata = pd.read_csv('/Users/enod/Development/fb-scrape/facebook-page-post-scraper/156915824368931_facebook_statuses.csv',dtype={'num_sads':float})

# %% [markdown]
# ## Хэрхэн groupby ашиглах вэ?

# %%
fbdata.head()
# Out:
#                           status_id  \
# 0  156915824368931_1125851687475335
# 1  156915824368931_1125254910868346
# 2  156915824368931_1125189747541529
# 3  156915824368931_1125116847548819
# 4  156915824368931_1123607134366457
#
#                                       status_message            link_name  \
# 0                    Өнөөдөр орой хүлээн авч үзээрэй      Timeline Photos
# 1  "Бригад" реалити шоуны оролцогчид Сэлэнгэ айма...                  NaN
# 2                                 Бригад реалити шоу  Шууд эфир /туршилт/
# 3                          Өнөөдөр орой манай ТВ-ээр      Timeline Photos
# 4                                          Өнөө орой      Timeline Photos
#
#   status_type                                        status_link  \
# 0       photo  https://www.facebook.com/mongoltv/photos/a.349...
# 1       video  https://www.facebook.com/mongoltv/videos/11252...
# 2       video  https://www.facebook.com/mongoltv/videos/11251...
# ...

# %%
fbdata.groupby('status_type').num_reactions.mean()
# Out:
# status_type
# event      53.193548
# link      116.288352
# photo     866.645661
# status    162.793407
# video     561.399804
# Name: num_reactions, dtype: float64

# %% [markdown]
# Зөвхөн тухайн field-г нь харая гэвэл

# %%
fbdata[fbdata['status_type']=='event'].num_reactions.mean()
# Out:
# 53.193548387096776

# %%
fbcomment.head()
# Out:
#                           comment_id                         status_id  \
# 0  1118055131588324_1118058484921322  156915824368931_1118055131588324
# 1  1118055131588324_1118066601587177  156915824368931_1118055131588324
# 2  1118055131588324_1118080791585758  156915824368931_1118055131588324
# 3  1118055131588324_1118208254906345  156915824368931_1118055131588324
# 4  1118055131588324_1118570608203443  156915824368931_1118055131588324
#
#   parent_id                                    comment_message  \
# 0       NaN  ХИЙГЭЭГҮЙ ХЭРГИЙН ТӨЛӨӨ НАМАЙГ БУРУУТГАЖ ЗАЛИЛ...
# 1       NaN                   kkk, buun modeluud ain, za uziy,
# 2       NaN                  Wowldoo huuhlduu huurhun l bnshde
# 3       NaN                          Page huudas bdiin   boluu
# 4       NaN                                           Teneguud
#
#          comment_author    comment_published  comment_likes
# 0            Bai Puujee  2016-07-25 02:12:51              0
# ...

# %%
fbcomment.groupby('comment_author').comment_likes.mean().head()
# Out:
# comment_author
# 'Chinbat Borkhuu    1.076923
# 'Unurbayar Ch       1.400000
# 'Б Хулан            0.000000
# 'Б' Лхагвацэрэн     0.000000
# 'Бүрнээ Ж.          0.000000
# Name: comment_likes, dtype: float64

# %% [markdown]
# #### Aggregation дараах байдлаар мөн хийж болно

# %%
fbdata.groupby('status_type').num_reactions.agg(['count', 'min', 'max', 'mean'])
# Out:
#              count  min    max        mean
# status_type
# event           62    3   1133   53.193548
# link           704    0  10274  116.288352
# photo          968    0  34388  866.645661
# status         455    0   7097  162.793407
# video         1023    0  21978  561.399804

# %% [markdown]
# #### groupby field араас нь шууд agg function залгавал бүх тоон утгатай талбарууд тооцоологдоно

# %%
fbdata.groupby('status_type').mean()
# Out:
#              num_reactions  num_comments  num_shares   num_likes  num_loves  \
# status_type
# event            53.193548      2.951613    0.000000   52.306452   0.306452
# link            116.288352      8.390625    9.788352  115.099432   0.103693
# photo           866.645661     42.952479   53.178719  859.728306   2.377066
# status          162.793407     30.527473    4.373626  160.059341   0.180220
# video           561.399804     76.950147   95.083089  543.732160   6.009775
#
#              num_wows  num_hahas  num_sads  num_angrys
# status_type
# event        0.451613   0.096774  0.000000    0.032258
# link         0.271307   0.363636  0.076705    0.372159
# photo        3.246901   0.496901  0.233471    0.563017
# status       0.193407   0.164835  0.578022    1.617582
# video        3.305963   2.956989  1.668622    3.709677

# %%
# %matplotlib inline

# %%
fbdata.groupby('status_type').num_reactions.agg(['count', 'mean']).plot(kind='bar')
